# %%
import pymongo

# Establish a connection to the MongoDB server
client = pymongo.MongoClient("mongodb://127.0.0.1:27017/")

# Specify the database and collection
db = client["Gridinsight"]
collection = db["new_billing_records"]

# %%
# Specify the database and collection
db = client["Gridinsight"]
collection = db["new_billing_records"]

# %%
# JSON document to be inserted
document = {
            "rate_charge": {
                "consumption_type": [
                    "Industrial",
                    "Residential",
                    "Commercial"
                ],
                "units_rc": [
                    1796394,
                    2348,
                    1190
                ],
                "rate_rc": [
                    8.12,
                    6.95,
                    12.83
                ],
                "charges_rs_rc": [
                    14586719.28,
                    16318.6,
                    15267.7
                ]
            },
            "current_consumption_details": {
                "current": [
                    2423788.5,
                    60778.5
                ],
                "previous": [
                    2383830.0,
                    60120.5
                ],
                "difference": [
                    39958.5,
                    658.0
                ],
                "multiplying_factor": [
                    45,
                    45
                ]
            },
            "tod": {
                "tod_zone": [
                    "00:00 Hrs-06:00 Hrs",
                    "06:00Hrs-09:00Hrs & 12:00Hrs-18:00Hrs",
                    "09:00 Hrs-12:00 Hrs",
                    "18:00 Hrs-22:00 Hrs"
                ],
                "rate_tod": [
                    -1.5,
                    0.0,
                    0.8,
                    1.1
                ],
                "units_tod": [
                    605760,
                    666622,
                    218356,
                    306847
                ],
                "demand_tod": [
                    2826,
                    2835,
                    2831,
                    2794
                ],
                "charges_rs_tod": [
                    -908640.0,
                    0.0,
                    174684.8,
                    337531.7
                ]
            },
            "demand_charge": {
                "bill_demand_kva": [
                    "2835"
                ],
                "rate_dc": [
                    "499.00"
                ],
                "average_pf": [
                    "0.999"
                ]
            },
            "billing_details": {
                "demand_charges": [
                    1414665
                ],
                "wheeling_charge_rate": [
                    "0.60"
                ],
                "wheeling_charge": [
                    "1079959.20"
                ],
                "energy_charges": [
                    "14618305.58"
                ],
                "tod_tariff_ec": [
                    "-396423.50"
                ],
                "fac_rate": [
                    "20.00"
                ],
                "electricity_duty": [
                    "6809.34"
                ],
                "bulk_consumption_rebate": [
                    "-249149.97"
                ],
                "tax_on_sale_rate": [
                    "19.04"
                ],
                "incremental_consumption_rebate": [
                    "0.00"
                ],
                "charges_for_excess_demand": [
                    "0.00"
                ],
                "tax_collection_at_source": [
                    "0.00"
                ],
                "debit_bill_adjustment": [
                    "0.00"
                ],
                "bill_as_per_merc": [
                    "17176069.70"
                ],
                "total_current_bill": [
                    "13583281.70"
                ],
                "current_interest": [
                    "0.00"
                ],
                "principle_arrears": [
                    "-4990.86"
                ],
                "interest_arrears": [
                    "0.00"
                ],
                "total_bill_rounded_rs": [
                    "13578290.00"
                ],
                "delayed_payment_charges": [
                    "214700.87"
                ],
                "fac": [
                    "359986.40"
                ],
                "tax_on_sale": [
                    "341917.65"
                ],
                "pf_penal_charges": [
                    "0"
                ]
            },
            "solar_net_meter_consumption": {
                "generation_unit": [
                    "0"
                ],
                "export": [
                    "0"
                ],
                "import": [
                    "0"
                ],
                "adjusted": [
                    "0"
                ],
                "bank": [
                    "0"
                ],
                "banking_charges": [
                    "0"
                ],
                "solar_capacity": [
                    "0"
                ]
            },
            "user": {
                "Consumer_No": [
                    510019000140
                ],
                "Pin_Code": [
                    442301
                ],
                "Consumer_Name": [
                    "M/S GIMATEX INDUSTRIES PVT. LTD"
                ],
                "user_id": [
                    22
                ],
            },
            "bill_info": {
                "Tariff": [
                    "102 HT-I A"
                ],
                "Connected_Load_KW": [
                    4901
                ],
                "Contract_Demand_KVA": [
                    3001
                ],
                "Con_Demand_KVA_Percent": [
                    70
                ],
                "Feeder_Voltage_KV": [
                    33
                ],
                "Prev_Highest_Bill_Demand_KVA": 2863,
                "SD_Held_Rs": 834552.86
            },
            "bill_history_table": {
                "Bill_Month": [
                    "Sep 2023",
                    "Aug 2023",
                    "Jul 2023",
                    "Jun 2023",
                    "May 2023",
                    "Apr 2023",
                    "Mar 2023",
                    "Feb 2023",
                    "Jan 2023",
                    "Dec 2022",
                    "Nov 2022",
                    "Oct 2022"
                ],
                "Units": [
                    1892095,
                    2135833,
                    2255450,
                    2076126,
                    2145069,
                    2190609,
                    2383987,
                    2239483,
                    2535880,
                    2336306,
                    2301757,
                    2425496
                ],
                "Bill_Demand_KVA": [
                    2863,
                    3285,
                    3308,
                    3226,
                    3061,
                    3409,
                    3378,
                    3735,
                    3742,
                    3482,
                    3137,
                    3578
                ],
                "Bill_Amount": [
                    18078204,
                    19936606,
                    20977812,
                    19326220,
                    19933093,
                    20482411,
                    22197906,
                    20991188,
                    23580436,
                    21727280,
                    21414798,
                    22538585
                ]
            },
            "reading_dates": {
                "current_date": [
                    "2023-11-31"
                ],
                "previous_date": [
                    "2023-10-30"
                ]
            }
        }

# %%
# Insert the document into the collection
collection.insert_one(document)
# Out:
# InsertOneResult(ObjectId('66794b98af0545502263e956'), acknowledged=True)

# %%
# Create indexes on Consumer_No and reading_dates.current_date
collection.create_index([("user.Consumer_No", 1)])
collection.create_index([("reading_dates.current_date", 1)])

# Query the document
query = {
    "user.Consumer_No": 510019000140,
    "reading_dates.current_date": "2023-10-31"
}

document = collection.find_one(query)

# Print the document
print(document)
# Out:
# {'_id': ObjectId('6679402faf0545502263e952'), 'rate_charge': {'consumption_type': ['Industrial', 'Residential', 'Commercial'], 'units_rc': [1796394, 2348, 1190], 'rate_rc': [8.12, 6.95, 12.83], 'charges_rs_rc': [14586719.28, 16318.6, 15267.7]}, 'current_consumption_details': {'current': [2423788.5, 60778.5], 'previous': [2383830.0, 60120.5], 'difference': [39958.5, 658.0], 'multiplying_factor': [45, 45]}, 'tod': {'tod_zone': ['00:00 Hrs-06:00 Hrs', '06:00Hrs-09:00Hrs & 12:00Hrs-18:00Hrs', '09:00 Hrs-12:00 Hrs', '18:00 Hrs-22:00 Hrs'], 'rate_tod': [-1.5, 0.0, 0.8, 1.1], 'units_tod': [605760, 666622, 218356, 306847], 'demand_tod': [2826, 2835, 2831, 2794], 'charges_rs_tod': [-908640.0, 0.0, 174684.8, 337531.7]}, 'demand_charge': {'bill_demand_kva': ['2835'], 'rate_dc': ['499.00'], 'average_pf': ['0.999']}, 'billing_details': {'demand_charges': [1414665], 'wheeling_charge_rate': ['0.60'], 'wheeling_charge': ['1079959.20'], 'energy_charges': ['14618305.58'], 'tod_tariff_ec': ['-396423.50
# ...

# %%
data = [{
            "rate_charge": {
                "consumption_type": [
                    "Industrial",
                    "Residential",
                    "Commercial"
                ],
                "units_rc": [
                    1491650,
                    0,
                    0
                ],
                "rate_rc": [
                    8.12,
                    6.95,
                    12.83
                ],
                "charges_rs_rc": [
                    12112198,
                    0,
                    0
                ]
            },
            "current_consumption_details": {
                "current": [
                    1456450,
                    1491650
                ],
                "previous": [
                    1456450,
                    1491650
                ],
                "difference": [
                    1456.45,
                    1491.65
                ],
                "multiplying_factor": [
                    1000,
                    1000
                ]
            },
            "tod": {
                "tod_zone": [
                    "00:00 Hrs-06:00 Hrs",
                    "06:00Hrs-09:00Hrs & 12:00Hrs-18:00Hrs",
                    "09:00 Hrs-12:00 Hrs",
                    "18:00 Hrs-22:00 Hrs"
                ],
                "rate_tod": [
                    -1.5,
                    0.0,
                    0.8,
                    1.1
                ],
                "units_tod": [
                    273450,
                    615100,
                    275850,
                    327250
                ],
                "demand_tod": [
                    4848,
                    5708,
                    5824,
                    5740
                ],
                "charges_rs_tod": [
                    -410175.0,
                    0.0,
                    220680.0,
                    359975.0
                ]
            },
            "demand_charge": {
                "bill_demand_kva": [
                    "5824"
                ],
                "rate_dc": [
                    "499.00"
                ],
                "average_pf": [
                    "0.976"
                ]
            },
            "billing_details": {
                "demand_charges": [
                    2906176
                ],
                "wheeling_charge_rate": [
                    "0.00"
                ],
                "wheeling_charge": [
                    "0.00"
                ],
                "energy_charges": [
                    "12112198.00"
                ],
                "tod_tariff_ec": [
                    "170480.00"
                ],
                "fac_rate": [
                    "0.00"
                ],
                "electricity_duty": [
                    "0.00"
                ],
                "bulk_consumption_rebate": [
                    "-206042.97"
                ],
                "tax_on_sale_rate": [
                    "18.00"
                ],
                "incremental_consumption_rebate": [
                    "-179432.25"
                ],
                "charges_for_excess_demand": [
                    "0.00"
                ],
                "tax_collection_at_source": [
                    "0.00"
                ],
                "debit_bill_adjustment": [
                    "0.00"
                ],
                "bill_as_per_merc": [
                    "0"
                ],
                "total_current_bill": [
                    "15065431.78"
                ],
                "current_interest": [
                    "0.00"
                ],
                "principle_arrears": [
                    "1.87"
                ],
                "interest_arrears": [
                    "0.00"
                ],
                "total_bill_rounded_rs": [
                    "15065430.00"
                ],
                "delayed_payment_charges": [
                    "188317.90"
                ],
                "fac": [
                    "0.00"
                ],
                "tax_on_sale": [
                    "262053.00"
                ],
                "pf_penal_charges": [
                    "0"
                ]
            },
            "solar_net_meter_consumption": {
                "generation_unit": [
                    "0"
                ],
                "export": [
                    "0"
                ],
                "import": [
                    "0"
                ],
                "adjusted": [
                    "0"
                ],
                "bank": [
                    "0"
                ],
                "banking_charges": [
                    "0"
                ],
                "solar_capacity": [
                    "0"
                ]
            },
            "user": {
                "Consumer_No": [
                    420819006720
                ],
                "Pin_Code": [
                    440018
                ],
                "Consumer_Name": [
                    "M/S SANVIJAY ROLLING &ENGINEERING LTD"
                ],
                "user_id": [
                    23
                ],
            },
            "bill_info": {
                "Tariff": [
                    "103 HT-I A old trf HT-I A"
                ],
                "Connected_Load_KW": [
                    63880
                ],
                "Contract_Demand_KVA": [
                    6812
                ],
                "Con_Demand_KVA_Percent": [
                    70
                ],
                "Feeder_Voltage_KV": [
                    220
                ],
                "Prev_Highest_Bill_Demand_KVA": 6464,
                "SD_Held_Rs": [
                    0
                ]
            },
            "bill_history_table": {
                "Bill_Month": [
                    "Apr 2023",
                    "Mar 2023",
                    "Feb 2023",
                    "Jan 2023",
                    "Dec 2022",
                    "Nov 2022",
                    "Oct 2022",
                    "Sep 2022",
                    "Aug 2022",
                    "Jul 2022",
                    "Jun 2022"
                ],
                "Units": [
                    1478650,
                    1254050,
                    1329150,
                    1429600,
                    1336500,
                    1499450,
                    1395800,
                    1366100,
                    1167000,
                    1231400,
                    1323050
                ],
                "Bill_Demand_KVA": [
                    6232,
                    6264,
                    6412,
                    5580,
                    5488,
                    6100,
                    6464,
                    6176,
                    6208,
                    6064,
                    5960
                ],
                "Bill_Amount": [
                    15321299,
                    13344366,
                    14034747,
                    14541735,
                    13728577,
                    15307956,
                    14599348,
                    14336398,
                    12550539,
                    13039379,
                    14640150
                ]
            },
            "reading_dates": {
                "current_date": [
                    "2023-05-31"
                ],
                "previous_date": [
                    "2023-04-30"
                ]
            }
        },
    {
            "rate_charge": {
                "consumption_type": [
                    "Industrial",
                    "Residential",
                    "Commercial"
                ],
                "units_rc": [
                    293872,
                    0,
                    0
                ],
                "rate_rc": [
                    6.89,
                    5.7,
                    10.95
                ],
                "charges_rs_rc": [
                    2024778.08,
                    0.0,
                    0.0
                ]
            },
            "current_consumption_details": {
                "current": [
                    331074.1,
                    335341.1
                ],
                "previous": [
                    301802.1,
                    305953.9
                ],
                "difference": [
                    29272.0,
                    29387.2
                ],
                "multiplying_factor": [
                    10.0,
                    10.0
                ]
            },
            "tod": {
                "tod_zone": [
                    "00:00 Hrs-06:00 Hrs",
                    "06:00Hrs-09:00Hrs & 12:00Hrs-18:00Hrs",
                    "09:00 Hrs-12:00 Hrs",
                    "18:00 Hrs-22:00 Hrs"
                ],
                "rate_tod": [
                    -1.5,
                    0.0,
                    0.8,
                    1.1
                ],
                "units_tod": [
                    98279,
                    110677,
                    38719,
                    46197
                ],
                "demand_tod": [
                    538,
                    570,
                    517,
                    538
                ],
                "charges_rs_tod": [
                    -147418.5,
                    0.0,
                    30975.2,
                    50816.7
                ]
            },
            "demand_charge": {
                "bill_demand_kva": [
                    "570"
                ],
                "rate_dc": [
                    "454.00"
                ],
                "average_pf": [
                    "0.996"
                ]
            },
            "billing_details": {
                "demand_charges": [
                    258780
                ],
                "wheeling_charge_rate": [
                    "0.55"
                ],
                "wheeling_charge": [
                    "161629.60"
                ],
                "energy_charges": [
                    "2024778.08"
                ],
                "tod_tariff_ec": [
                    "-65626.60"
                ],
                "fac_rate": [
                    "15.00"
                ],
                "electricity_duty": [
                    "0.00"
                ],
                "bulk_consumption_rebate": [
                    "-27297.18"
                ],
                "tax_on_sale_rate": [
                    "19.04"
                ],
                "incremental_consumption_rebate": [
                    "0.00"
                ],
                "charges_for_excess_demand": [
                    "0.00"
                ],
                "tax_collection_at_source": [
                    "0.00"
                ],
                "debit_bill_adjustment": [
                    "0.00"
                ],
                "bill_as_per_merc": [
                    "0"
                ],
                "total_current_bill": [
                    "2452074.21"
                ],
                "current_interest": [
                    "0.00"
                ],
                "principle_arrears": [
                    "-287486.81"
                ],
                "interest_arrears": [
                    "0.00"
                ],
                "total_bill_rounded_rs": [
                    "2164590.00"
                ],
                "delayed_payment_charges": [
                    "30650.93"
                ],
                "fac": [
                    "44080.80"
                ],
                "tax_on_sale": [
                    "55729.51"
                ],
                "pf_penal_charges": [
                    "0"
                ]
            },
            "solar_net_meter_consumption": {
                "generation_unit": [
                    "0"
                ],
                "export": [
                    "0"
                ],
                "import": [
                    "0"
                ],
                "adjusted": [
                    "0"
                ],
                "bank": [
                    "0"
                ],
                "banking_charges": [
                    "0"
                ],
                "solar_capacity": [
                    "0"
                ]
            },
            "user": {
                "Consumer_No": [
                    411359022410
                ],
                "Pin_Code": [
                    441122
                ],
                "Consumer_Name": [
                    "Nubeno Healthcare Private Limited"
                ],
                "user_id": [
                    24
                ],
            },
            "bill_info": {
                "Tariff": [
                    "101 HT-I A old trf HT-I A"
                ],
                "Connected_Load_KW": [
                    700
                ],
                "Contract_Demand_KVA": [
                    800
                ],
                "Con_Demand_KVA_Percent": [
                    65
                ],
                "Feeder_Voltage_KV": [
                    11
                ],
                "Prev_Highest_Bill_Demand_KVA": 586,
                "SD_Held_Rs": 1591776
            },
            "bill_history_table": {
                "Bill_Month": [
                    "Apr 2022",
                    "Mar 2022",
                    "Feb 2022",
                    "Jan 2022",
                    "Dec 2021",
                    "Nov 2021",
                    "Oct 2021",
                    "Sep 2021",
                    "Aug 2021",
                    "Jul 2021",
                    "Jun 2021",
                    "May 2021"
                ],
                "Units": [
                    281615,
                    244555,
                    232837,
                    243951,
                    238323,
                    181364,
                    198269,
                    219805,
                    229961,
                    222640,
                    180938,
                    179866
                ],
                "Bill_Demand_KVA": [
                    586,
                    488,
                    480,
                    480,
                    480,
                    480,
                    480,
                    480,
                    480,
                    480,
                    480,
                    480
                ],
                "Bill_Amount": [
                    2366674,
                    2060529,
                    1936468,
                    2017252,
                    1977091,
                    1560001,
                    1685142,
                    1840681,
                    1914881,
                    1864426,
                    1553938,
                    1543529
                ]
            },
            "reading_dates": {
                "current_date": [
                    "2022-05-31"
                ],
                "previous_date": [
                    "2022-04-30"
                ]
            }
        },
    {
            "rate_charge": {
                "consumption_type": [
                    "Industrial",
                    "Residential",
                    "Commercial"
                ],
                "units_rc": [
                    1491650,
                    0,
                    0
                ],
                "rate_rc": [
                    8.12,
                    6.95,
                    12.83
                ],
                "charges_rs_rc": [
                    12112198,
                    0,
                    0
                ]
            },
            "current_consumption_details": {
                "current": [
                    1456450,
                    1491650
                ],
                "previous": [
                    1456450,
                    1491650
                ],
                "difference": [
                    1456.45,
                    1491.65
                ],
                "multiplying_factor": [
                    1000,
                    1000
                ]
            },
            "tod": {
                "tod_zone": [
                    "00:00 Hrs-06:00 Hrs",
                    "06:00Hrs-09:00Hrs & 12:00Hrs-18:00Hrs",
                    "09:00 Hrs-12:00 Hrs",
                    "18:00 Hrs-22:00 Hrs"
                ],
                "rate_tod": [
                    -1.5,
                    0.0,
                    0.8,
                    1.1
                ],
                "units_tod": [
                    273450,
                    615100,
                    275850,
                    327250
                ],
                "demand_tod": [
                    4848,
                    5708,
                    5824,
                    5740
                ],
                "charges_rs_tod": [
                    -410175.0,
                    0.0,
                    220680.0,
                    359975.0
                ]
            },
            "demand_charge": {
                "bill_demand_kva": [
                    "5824"
                ],
                "rate_dc": [
                    "499.00"
                ],
                "average_pf": [
                    "0.976"
                ]
            },
            "billing_details": {
                "demand_charges": [
                    2906176
                ],
                "wheeling_charge_rate": [
                    "0.00"
                ],
                "wheeling_charge": [
                    "0.00"
                ],
                "energy_charges": [
                    "12112198.00"
                ],
                "tod_tariff_ec": [
                    "170480.00"
                ],
                "fac_rate": [
                    "0.00"
                ],
                "electricity_duty": [
                    "0.00"
                ],
                "bulk_consumption_rebate": [
                    "-206042.97"
                ],
                "tax_on_sale_rate": [
                    "18.00"
                ],
                "incremental_consumption_rebate": [
                    "-179432.25"
                ],
                "charges_for_excess_demand": [
                    "0.00"
                ],
                "tax_collection_at_source": [
                    "0.00"
                ],
                "debit_bill_adjustment": [
                    "0.00"
                ],
                "bill_as_per_merc": [
                    "0"
                ],
                "total_current_bill": [
                    "15065431.78"
                ],
                "current_interest": [
                    "0.00"
                ],
                "principle_arrears": [
                    "1.87"
                ],
                "interest_arrears": [
                    "0.00"
                ],
                "total_bill_rounded_rs": [
                    "15065430.00"
                ],
                "delayed_payment_charges": [
                    "188317.90"
                ],
                "fac": [
                    "0.00"
                ],
                "tax_on_sale": [
                    "262053.00"
                ],
                "pf_penal_charges": [
                    "0"
                ]
            },
            "solar_net_meter_consumption": {
                "generation_unit": [
                    "0"
                ],
                "export": [
                    "0"
                ],
                "import": [
                    "0"
                ],
                "adjusted": [
                    "0"
                ],
                "bank": [
                    "0"
                ],
                "banking_charges": [
                    "0"
                ],
                "solar_capacity": [
                    "0"
                ]
            },
            "user": {
                "Consumer_No": [
                    420819006720
                ],
                "Pin_Code": [
                    440018
                ],
                "Consumer_Name": [
                    "M/S SANVIJAY ROLLING &ENGINEERING LTD"
                ],
                "user_id": [
                    22
                ],
            },
            "bill_info": {
                "Tariff": [
                    "103 HT-I A old trf HT-I A"
                ],
                "Connected_Load_KW": [
                    63880
                ],
                "Contract_Demand_KVA": [
                    6812
                ],
                "Con_Demand_KVA_Percent": [
                    70
                ],
                "Feeder_Voltage_KV": [
                    220
                ],
                "Prev_Highest_Bill_Demand_KVA": 6464,
                "SD_Held_Rs": [
                    0
                ]
            },
            "bill_history_table": {
                "Bill_Month": [
                    "Apr 2023",
                    "Mar 2023",
                    "Feb 2023",
                    "Jan 2023",
                    "Dec 2022",
                    "Nov 2022",
                    "Oct 2022",
                    "Sep 2022",
                    "Aug 2022",
                    "Jul 2022",
                    "Jun 2022"
                ],
                "Units": [
                    1478650,
                    1254050,
                    1329150,
                    1429600,
                    1336500,
                    1499450,
                    1395800,
                    1366100,
                    1167000,
                    1231400,
                    1323050
                ],
                "Bill_Demand_KVA": [
                    6232,
                    6264,
                    6412,
                    5580,
                    5488,
                    6100,
                    6464,
                    6176,
                    6208,
                    6064,
                    5960
                ],
                "Bill_Amount": [
                    15321299,
                    13344366,
                    14034747,
                    14541735,
                    13728577,
                    15307956,
                    14599348,
                    14336398,
                    12550539,
                    13039379,
                    14640150
                ]
            },
            "reading_dates": {
                "current_date": [
                    "2023-05-31"
                ],
                "previous_date": [
                    "2023-04-30"
                ]
            }
        }
]

# %%
# Insert the document into the collection
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('66794033af0545502263e953'), ObjectId('66794033af0545502263e954'), ObjectId('66794033af0545502263e955')], acknowledged=True)

# %%
# Query to retrieve all Consumer_No values
query = {
    "user.Consumer_No": {"$exists": True}
}

# Project only the Consumer_No field
projection = {
    "user.Consumer_No": 1,
    "_id": 0  # Exclude the _id field
}

# Execute the query and retrieve all documents matching the query
documents = collection.find(query, projection)

# Extract all Consumer_No values
consumer_ids = [doc["user"]["Consumer_No"] for doc in documents]

# Print the list of all Consumer_No values
print(consumer_ids)
# Out:
# [[411359022410], [420819006720], [420819006720], [510019000140]]

# %%
# Query to retrieve all bill_info data
query = {
    "bill_info": {"$exists": True}
}

# Project only the bill_info field
projection = {
    "bill_info": 1,
    "_id": 0  # Exclude the _id field
}

# Execute the query and retrieve all documents matching the query
documents = collection.find(query, projection)

# Extract all bill_info data
bill_info_list = [doc["bill_info"] for doc in documents]

# Print the list of all bill_info data
for bill_info in bill_info_list:
    print(bill_info)
# Out:
# {'Tariff': ['102 HT-I A'], 'Connected_Load_KW': [4901], 'Contract_Demand_KVA': [3001], 'Con_Demand_KVA_Percent': [70], 'Feeder_Voltage_KV': [33], 'Prev_Highest_Bill_Demand_KVA': 2863, 'SD_Held_Rs': 834552.86}
# {'Tariff': ['103 HT-I A old trf HT-I A'], 'Connected_Load_KW': [63880], 'Contract_Demand_KVA': [6812], 'Con_Demand_KVA_Percent': [70], 'Feeder_Voltage_KV': [220], 'Prev_Highest_Bill_Demand_KVA': 6464, 'SD_Held_Rs': [0]}
# {'Tariff': ['101 HT-I A old trf HT-I A'], 'Connected_Load_KW': [700], 'Contract_Demand_KVA': [800], 'Con_Demand_KVA_Percent': [65], 'Feeder_Voltage_KV': [11], 'Prev_Highest_Bill_Demand_KVA': 586, 'SD_Held_Rs': 1591776}
# {'Tariff': ['103 HT-I A old trf HT-I A'], 'Connected_Load_KW': [63880], 'Contract_Demand_KVA': [6812], 'Con_Demand_KVA_Percent': [70], 'Feeder_Voltage_KV': [220], 'Prev_Highest_Bill_Demand_KVA': 6464, 'SD_Held_Rs': [0]}

# %%
# Specify the consumer id
consumer_id = 510019000140  # Replace with the actual Consumer_No you want to query
user_id = 22

# Query to retrieve the bill_info data for the specified consumer
query = {
    "user.Consumer_No": consumer_id,
    "user.user_id": user_id
}

# Project only the bill_info field
projection = {
    "bill_info": 1,
    "_id": 0  # Exclude the _id field
}

# Execute the query and retrieve the document matching the query
document = collection.find_one(query, projection)

# Check if the document exists and print the bill_info
if document:
    print(document["bill_info"])
else:
    print(f"No record found for Consumer_No: {consumer_id}")
# Out:
# {'Tariff': ['102 HT-I A'], 'Connected_Load_KW': [4901], 'Contract_Demand_KVA': [3001], 'Con_Demand_KVA_Percent': [70], 'Feeder_Voltage_KV': [33], 'Prev_Highest_Bill_Demand_KVA': 2863, 'SD_Held_Rs': 834552.86}

# %% [markdown]
# # Fetching Functions

# %%
def fetch_user_id(user_id):
    """
    Fetches the user_id for a given user_id.
    returns the user_id if found, otherwise returns None.
    """
    # Query to retrieve the User_Id for the specified User_Id
    query = {
        "user.user_id": user_id
    }

    # Project only the User_Id field
    projection = {
        "user.user_id": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve the document matching the query
    document = collection.find_one(query, projection)

    # Return the User_Id if found, otherwise return None
    return document["user"]["user_id"][0] if document else None

# Example usage
user_id = 22  # Replace with the actual User_Id you want to query
result = fetch_user_id(user_id)
print(type(result))
# Out:
# <class 'int'>

# %%
def fetch_consumer_id_for_user(user_id, consumer_id):
    """
    Fetches the consumer_id for a given consumer_id and user_id.
    Returns the consumer_id if found, otherwise returns None.
    """
    # Query to retrieve the consumer_id for the specified consumer_id and user_id
    query = {
        "user.user_id": user_id,
        "user.consumer_id": int(consumer_id)
    }

    # Project only the consumer_id field
    projection = {
        "user.consumer_id": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve the document matching the query
    document = collection.find_one(query, projection)

    # Return the consumer_id if found, otherwise return None
    return document["user"]["consumer_id"][0] if document else None

# Example usage
consumer_id = '410039008200'  # Replace with the actual Consumer_No you want to query
user_id = 22  # Replace with the actual user_id you want to query
result = fetch_consumer_id_for_user(user_id, consumer_id)
print(result)
print(type(result))
# Out:
# 410039008200
# <class 'bson.int64.Int64'>

# %%
def fetch_consumer_bill_history_months(user_id, consumer_id):   ### Not needed (writen for practice only)
    """
    Fetches the bill history table months based on the consumer ID.

    :param user_id: The ID of the user.
    :param consumer_id: The ID of the consumer.

    :return: A set containing the bill history months fetched based on the consumer ID.
             The format of each month is 'YYYY-MM-DD'.
    """
    # Query to find documents matching user_id and consumer_id
    query = {
        "user.user_id": user_id,
        "user.Consumer_No": consumer_id
    }

    # Projection to get only the bill_info.Tariff field
    projection = {
        "bill_history_table.Bill_Month": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve all documents matching the query
    cursor = collection.find(query, projection)

    # Extract and format the bill months, converting to a set for uniqueness
    bill_months = set()
    for doc in cursor:
        if "bill_history_table" in doc:
            bill_months.update(doc["bill_history_table"]["Bill_Month"])

    return bill_months

# Example usage
user_id = 22  # Replace with the actual user_id you want to query
consumer_id = 510019000140  # Replace with the actual Consumer_No you want to query
results = fetch_consumer_bill_history_months(user_id, consumer_id)
print(results)
# Out:
# {'Sep 2023', 'Nov 2022', 'Oct 2022', 'Mar 2023', 'Feb 2023', 'Jun 2023', 'May 2023', 'Dec 2022', 'Jan 2023', 'Aug 2023', 'Apr 2023', 'Jul 2023'}

# %%
def fetch_user_id(user_id):
    """
    Fetches the user_id for a given user_id.
    Returns the user_id as a string if found, otherwise returns None.
    """
    # Query to retrieve the User_Id for the specified user_id
    query = {
        "user.user_id": user_id
    }

    # Projection to get only the user_id field
    projection = {
        "user.user_id": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve the document matching the query
    document = collection.find_one(query, projection)

    # Return the user_id as a string if found, otherwise return None
    if document and "user" in document and "user_id" in document["user"]:
        return str(document["user"]["user_id"]).strip('[]')  # Convert to string and strip brackets if necessary
    else:
        return None

# Example usage
user_id_to_find = 22  # Replace with the actual user_id you want to query
result = fetch_user_id(user_id_to_find)
print(type(result))
# Out:
# <class 'str'>

# %%
def fetch_current_reading_date(user_id, consumer_id):
    """
    Fetches all current_reading dates for a given user_id and consumer_id.
    Returns a list of current_reading dates if found, otherwise returns an empty list.
    """
    # Query to retrieve the current_reading date for the specified user_id and consumer_id
    query = {
        "user.user_id": user_id,
        "user.consumer_id": int(consumer_id)
    }

    # Project only the reading_dates.current_date field
    projection = {
        "reading_dates.current_date": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve all documents matching the query
    cursor = collection.find(query, projection)

    # Extract all current_reading dates from the cursor and flatten the list
    current_reading_dates = [date for doc in cursor if "reading_dates" in doc for date in doc["reading_dates"]["current_date"]]

    return current_reading_dates

# Example usage
user_id = 22 
consumer_id = '410039008200'
result = fetch_current_reading_date(user_id, consumer_id)
print(result)
# Out:
# ['2023-06-30', '2023-06-30', '2023-06-30', '2023-06-30']

# %%
def verify_and_return_consumer_no(user_id, consumer_id):
    """
    Verifies if a consumer_id exists based on user_id and consumer_id.
    Returns the consumer_no if it exists, otherwise returns None.
    """
    # Query to check for the existence of the specified user_id and consumer_id
    query = {
        "user.user_id": user_id,
        "user.Consumer_No": {"$in": [consumer_id, int(consumer_id)]}  # Handle both int and str types
    }

    # Projection to get only the Consumer_No field
    projection = {
        "user.Consumer_No": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve the document matching the query
    document = collection.find_one(query, projection)

    # Return the Consumer_No if found, otherwise return None
    return document["user"]["Consumer_No"] if document else None

# Example usage
user_id_to_check = 22
consumer_id_to_check = '510019000140'
result = verify_and_return_consumer_no(user_id_to_check, consumer_id_to_check)
if result:
    print(f"Consumer ID found: {result}")
else:
    print("Consumer ID not found")
print(type(consumer_id_to_check))
# Out:
# Consumer ID found: [510019000140]
# <class 'str'>

# %%
def fetch_consumer_id_for_user(user_id, consumer_id):
    """
    Fetches the consumer_id for a given consumer_id and user_id.
    Returns the consumer_id if found, otherwise returns None.
    """
    # Query to retrieve the Consumer_No for the specified consumer_id and user_id
    query = {
        "user.user_id": user_id,
        "user.consumer_id": int(consumer_id)
    }

    # Project only the consumer_id field
    projection = {
        "user.consumer_id": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve the document matching the query
    document = collection.find_one(query, projection)
    print(document)

    # Return the Consumer_No if found, otherwise return None
    if document and "user" in document:
        user_data = document["user"]
        if isinstance(user_data, list) and user_data:
            return user_data[0]["consumer_id"]
        elif isinstance(user_data, dict):
            return user_data["consumer_id"]
    return None


# Example usage
user_id_to_check = 22
consumer_id_to_check = '410039008200'
result = fetch_consumer_id_for_user(user_id_to_check, consumer_id_to_check)
print(result)
# Out:
# {'user': [{'consumer_id': 410039008200}]}
# 410039008200

# %%
def mongo_insertion(pdf_path: str, user_id: int, collection) -> dict:
    """
    Extracts information from a PDF bill file, processes it, and saves it to a database.

    This function orchestrates the extraction and storage process for bill-related information
    obtained from the provided PDF file. It handles user information, bill details, consumption dates,
    bill history, and other relevant tables.

    :param pdf_path: The file path to the PDF document containing the bill information.
    :param user_id: The ID of the user associated with the bill.
    :param collection: The MongoDB collection where the data will be stored.

    :return: A dictionary with the status, message, user_id, and consumer_id.
    """
    try:
        # Create an instance of ExtractionAndDisplay
        extraction = ExtractionAndDisplay(pdf_path)
        # Extract user information
        user_extraction_result = extraction.user()
        user_table = process_user_table(user_extraction_result)
        consumer_id = str(user_table.iloc[0]['consumer_id'])
        db_user_id = fetch_user_id(user_id)
        db_consumer_id = fetch_consumer_id_for_user(user_id, consumer_id)
        status = 200
        message = []

        def prepare_and_insert(tables, user_id, collection):
            # Convert each DataFrame to a dictionary
            for key, value in tables.items():
                if isinstance(value, pd.DataFrame):
                    tables[key] = value.to_dict(orient='list')
            # Insert each table into MongoDB
            collection.insert_one(tables)

        if db_user_id and db_consumer_id:
            date_table = extraction.reading_dates_table()
            current_date = date_table.iloc[0]['current_date']
            dates_in_db = fetch_current_reading_date(user_id, consumer_id)

            if current_date in dates_in_db:
                status = 202
                message = 'consumer and bill already exists'
                return {'status': status, 'message': message, "user_id": user_id, "consumer_id": consumer_id}

            message = 'adding new bill for a consumer'
            user_table['user_id'] = user_id
            tables = extraction.other_tables()
            tables['user'] = user_table
            tables['reading_dates'] = date_table

            prepare_and_insert(tables, user_id, collection)

        else:
            # Save 'user' data if the user does not exist
            if user_id:
                message = 'adding new consumer and his bill for a user'
            else:
                message = 'adding new user and new consumer and his bill'
            user_table['user_id'] = user_id
            date_table = extraction.reading_dates_table()
            # Insert user table
            tables = extraction.other_tables()
            tables['user'] = user_table
            tables['reading_dates'] = date_table

            prepare_and_insert(tables, user_id, collection)

        return {"status": status, "message": message, "user_id": user_id, "consumer_id": consumer_id}

    except Exception as e:
        return {"status": 500, "message": f"An error occurred: {str(e)}", "user_id": user_id, "consumer_id": None}

# %%
import pymongo

# Establish a connection to the MongoDB server
client = pymongo.MongoClient("mongodb://127.0.0.1:27017/")

# Specify the database and collection
db = client["Gridinsight"]
collection = db["new_billing_records"]

# %%
def fetch_consumer_details(user_id):
    """
    Fetches the consumer_id and name for a given user_id.
    Returns a list of dictionaries with label and value.
    """
    # Query to retrieve the consumer_id and name for the specified user_id
    query = {
        "user.user_id": user_id
    }

    # Project only the necessary fields
    projection = {
        "user.consumer_id": 1,
        "user.name": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve the documents matching the query
    documents = collection.find(query, projection)

    unique_values = set()
    result_list = []

    for doc in documents:
        if "user" in doc:
            consumer_id = doc["user"].get("consumer_id", [None])[0]
            name = doc["user"].get("name", [None])[0]
            if consumer_id and name:
                label = f"{consumer_id} - {name}"
                value = consumer_id
                if value not in unique_values:
                    unique_values.add(value)
                    result_list.append({"label": label, "value": value})

    return result_list

# Example usage
user_id = 25
result_list = fetch_consumer_details(user_id)
print(result_list)
# Out:
# []

# %% [markdown]
# ## Functions for Overview

# %%
import pandas as pd


def fetch_user_table(user_id, consumer_id):
    """
    Fetches and consolidates user tables for the given user_id and consumer_id.
    Returns a sorted and deduplicated DataFrame.
    """
    query = {"user.user_id": user_id, "user.consumer_id": int(consumer_id)}
    projection = {"user": 1, "_id": 0}

    cursor = collection.find(query, projection)
    user_data = [pd.DataFrame(doc["user"]) for doc in cursor if "user" in doc]

    if user_data:
        df = pd.concat(user_data).drop_duplicates().reset_index(drop=True)
    else:
        df = pd.DataFrame()

    return df


# Example usage
user_id_to_check = 22
consumer_id_to_check = 410039008200
result = fetch_user_table(user_id_to_check, consumer_id_to_check)
print(result)  # Should print the user table or None
# Out:
#     consumer_id  pincode                               name  user_id
# 0  410039008200   440008  M/S HALDIRAM FOODS INT. PVT. LTD.       22

# %%
def fetch_bill_info_and_reading_dates(user_id, consumer_id):
    """
    Fetches and consolidates bill_info tables and reading dates for the given user_id and consumer_id.
    Adds the current reading date to each corresponding record in the bill_info table.
    Returns a sorted and deduplicated DataFrame.
    """
    query = {"user.user_id": user_id, "user.consumer_id": int(consumer_id)}
    projection = {"bill_info": 1, "reading_dates": 1, "_id": 0}

    cursor = collection.find(query, projection)
    bill_info_data = []
    for doc in cursor:
        if "bill_info" in doc and "reading_dates" in doc:
            df = pd.DataFrame(doc["bill_info"])
            current_date = doc["reading_dates"].get("current_date", [None])[0]
            df["current_reading_date"] = current_date
            bill_info_data.append(df)

    if bill_info_data:
        df = pd.concat(bill_info_data).drop_duplicates().reset_index(drop=True)
    else:
        df = pd.DataFrame()

    return df

user_id_to_check = 22
consumer_id_to_check = 410039008200
result = fetch_bill_info_and_reading_dates(user_id_to_check, consumer_id_to_check)
result  # Should print the user table or None
# Out:
#                       tariff  connected_load_kw  contract_demand_kva  \
# 0  102 HT-I A old trf HT-I A               2900                 2500
# 1  102 HT-I A old trf HT-I A               2900                 2500
# 2  102 HT-I A old trf HT-I A               2900                 2500
#
#    percentage_contract_demand  feeder_voltage_kv  \
# 0                          70                 33
# 1                          70                 33
# 2                          70                 33
#
#    prev_highest_bill_demand_kva  sd_held_rs current_reading_date
# 0                          1933           0           2023-06-30
# 1                          1890           0           2023-07-31
# 2                          1890           0           2023-08-31

# %%
def fetch_billing_details(user_id, consumer_id):
    """
    Fetches the billing details table for a given user_id and consumer_id.
    Returns a sorted and deduplicated DataFrame.
    """
    query = {"user.user_id": user_id, "user.consumer_id": int(consumer_id)}
    projection = {"billing_details": 1, "_id": 0}

    cursor = collection.find(query, projection)
    billing_details_data = []
    for doc in cursor:
        if "billing_details" in doc:
            df = pd.DataFrame(doc["billing_details"])
            billing_details_data.append(df)

    if billing_details_data:
        df = pd.concat(billing_details_data).drop_duplicates().reset_index(drop=True)
    else:
        df = pd.DataFrame()

    return df

user_id_to_check = 22
consumer_id_to_check = 410039008200
result = fetch_billing_details(user_id_to_check, consumer_id_to_check)
result  # Should print the user table or None
# Out:
#    demand_charges wheeling_charge_rate wheeling_charge energy_charges  \
# 0          873250                 0.60       371053.80     5021594.76
# 1          873250                 0.60       338567.40     4581945.48
# 2          899198                 0.60       415704.60     5625868.92
#
#   tod_tariff_ec fac_rate electricity_duty bulk_consumption_rebate  \
# 0     -85249.70     0.00             0.00               -84191.90
# 1     -67488.50     0.00             0.00               -75398.91
# 2     -76021.90     0.00             0.00               -96277.38
#
#   tax_on_sale_rate incremental_consumption_rebate  ... bill_as_per_merc  \
# 0            18.00                      -25813.50  ...                0
# 1            18.00                           0.00  ...                0
# 2            18.00                      -81188.25  ...                0
#
#   total_current_bill current_interest principle_arrears interest_arrears  \
# ...

# %%
def fetch_bill_history_table(user_id, consumer_id):
    """
    Fetches the bill history table for a given user_id and consumer_id.
    Returns the bill history table as a DataFrame if found, otherwise returns an empty DataFrame.
    """
    # Query to retrieve the bill history for the specified user_id and consumer_id
    query = {
        "user.user_id": user_id,
        "user.consumer_id": int(consumer_id)  # Ensure consumer_id is an integer
    }

    # Projection to get only the bill history table
    projection = {
        "bill_history_table": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve the documents matching the query
    cursor = collection.find(query, projection)

    # List to store DataFrames
    bill_history_data = []

    # Process each document in the cursor
    for document in cursor:
        if "bill_history_table" in document:
            bill_history_data.append(pd.DataFrame(document["bill_history_table"]))

    # Concatenate all DataFrames and drop duplicates, if any
    if bill_history_data:
        df = pd.concat(bill_history_data).drop_duplicates().reset_index(drop=True)
        df['bill_month'] = pd.to_datetime(df['bill_month'])
        df = df.sort_values(by='bill_month').reset_index(drop=True)
    else:
        df = pd.DataFrame()

    return df


user_id_to_check = 22
consumer_id_to_check = 410039008200
result = fetch_bill_history_table(user_id_to_check, consumer_id_to_check)
result
# Out:
#    bill_month  units_bh  bill_demand_kva  bill_amount
# 0  2022-06-30    549003             1874      6006375
# 1  2022-07-31    672776             1933      6766182
# 2  2022-08-31    763842             1855      7504947
# 3  2022-09-30    741528             1890      7340860
# 4  2022-10-31    471846             1730      4897346
# 5  2022-11-30    489174             1625      4982500
# 6  2022-12-31    707645             1674      6890497
# 7  2023-01-31    618656             1625      6092238
# 8  2023-02-28    603544             1625      5956199
# 9  2023-03-31    616082             1625      6074200
# 10 2023-04-30    685631             1750      6833537
# 11 2023-05-31    526712             1750      5418736
# 12 2023-06-30    618423             1750      6207662
# 13 2023-07-31    564279             1750      5752344

# %%
def fetch_rate_charge_table(user_id, consumer_id):
    """
    Fetches the rate charge table for a given user_id and consumer_id.
    Returns the rate charge table as a DataFrame if found, otherwise returns an empty DataFrame.
    """
    # Query to retrieve the rate charge for the specified user_id and consumer_id
    query = {
        "user.user_id": user_id,
        "user.consumer_id": int(consumer_id)  # Ensure consumer_id is an integer
    }

    # Projection to get only the rate charge table
    projection = {
        "rate_charge": 1,
        "_id": 0  # Exclude the _id field
    }

    # Execute the query and retrieve all documents matching the query
    cursor = collection.find(query, projection)

    # Initialize empty lists to store data
    consumption_types = []
    units_rc = []
    rate_rc = []
    charges_rs_rc = []

    # Iterate over the cursor and extract data
    for document in cursor:
        if "rate_charge" in document:
            rate_charge_data = document["rate_charge"]
            consumption_types.extend(rate_charge_data["consumption_type"])
            units_rc.extend(rate_charge_data["units_rc"])
            rate_rc.extend(rate_charge_data["rate_rc"])
            charges_rs_rc.extend(rate_charge_data["charges_rs_rc"])

    # Create DataFrame from lists
    df = pd.DataFrame({
        "consumption_type": consumption_types,
        "units_rc": units_rc,
        "rate_rc": rate_rc,
        "charges_rs_rc": charges_rs_rc
    })
    return df

user_id_to_check = 22
consumer_id_to_check = 410039008200
result = fetch_rate_charge_table(user_id_to_check, consumer_id_to_check)
result
# Out:
#   consumption_type  units_rc  rate_rc  charges_rs_rc
# 0       Industrial    618423     8.12     5021594.76
# 1      Residential         0     6.95           0.00
# 2       Commercial         0    12.83           0.00
# 3       Industrial    564279     8.12     4581945.48
# 4      Residential         0     6.95           0.00
# 5       Commercial         0    12.83           0.00
# 6       Industrial    692841     8.12     5625868.92
# 7      Residential         0     6.95           0.00
# 8       Commercial         0    12.83           0.00
